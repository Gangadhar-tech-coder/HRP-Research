# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
df = pd.read_csv("bcancer.csv")

# If there is a label column, drop it
# (common names: 'diagnosis', 'label', 'target')
X = df.select_dtypes(include=[np.number]).values

print(X.shape)
# Out:
# (569, 32)

# %%
import numpy as np
from sklearn.random_projection import GaussianRandomProjection
from sklearn.metrics import pairwise_distances

# %%
results_bcancer = []

for alpha in alphas:
    X_hrp = hrp_alpha(X, n_components, alpha)
    err = distortion(X, X_hrp)
    results_bcancer.append(err)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 results_bcancer = []
#       3 for alpha in alphas:
# ----> 4     X_hrp = hrp_alpha(X, n_components, alpha)
#       5     err = distortion(X, X_hrp)
#       6     results_bcancer.append(err)
#
# NameError: name 'hrp_alpha' is not defined
